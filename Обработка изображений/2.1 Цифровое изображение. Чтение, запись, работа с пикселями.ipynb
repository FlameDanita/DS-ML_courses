# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
img = plt.imread('tiger-color.png')
plt.imshow(img)

# %%
img.shape # 600 - количество строк, 800 - количество столбцов, 3 - количество каналов (цветов)
# Out:
# (601, 801, 3)

# %%
img[383, 374] # Возвращает RGB-тройку чисел, кодирующих цвет кокретного пикселя
# Out:
# array([0.8       , 0.45882353, 0.30980393], dtype=float32)

# %%
plt.imshow(img[333:453, 324:424]) # нос

# %%
img[383, 374] = [255, 255, 0] # Изменяем цвет пикселя на носу тигра с оранжевого на жёлтый

# %%
plt.imshow(img[333:453, 324:424])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imsave('tiger-yellow-nose.png', img) # Сохраняем тигра с жёлтой точкой на носу
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plt.imsave('tiger-yellow-nose.png', img) # Сохраняем тигра с жёлтой точкой на носу
#
# File c:\Users\Никита Широкопетлев\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2173, in imsave(fname, arr, **kwargs)
#    2171 @_copy_docstring_and_deprecators(matplotlib.image.imsave)
#    2172 def imsave(fname, arr, **kwargs):
# -> 2173     return matplotlib.image.imsave(fname, arr, **kwargs)
#
# File c:\Users\Никита Широкопетлев\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:1650, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1648     sm = cm.ScalarMappable(cmap=cmap)
#    1649     sm.set_clim(vmin, vmax)
# -> 1650     rgba = sm.to_rgba(arr, bytes=True)
#    1651 if pil_kwargs is None:
# ...

# %%
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

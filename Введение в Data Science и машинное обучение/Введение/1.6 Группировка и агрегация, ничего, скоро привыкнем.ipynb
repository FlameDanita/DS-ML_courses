# %%
import pandas as pd
import numpy as np

# %%
df_dota2 = pd.read_csv('dota_hero_stats.csv')

# %%
df_dota2.groupby('legs').count()
# Out:
#       Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0             11           11  11              11    11            11     11
# 2             95           95  95              95    95            95     95
# 4              7            7   7               7     7             7      7
# 6              3            3   3               3     3             3      3
# 8              1            1   1               1     1             1      1

# %%
df_dota2.groupby(['attack_type', 'primary_attr']).count()
# Out:
#                           Unnamed: 0  id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi                   19  19    19              19    19     19
#             int                    2   2     2               2     2      2
#             str                   35  35    35              35    35     35
# Ranged      agi                   18  18    18              18    18     18
#             int                   40  40    40              40    40     40
#             str                    3   3     3               3     3      3

# %%
df_lupa_pupa = pd.read_csv('accountancy.csv')

# %%
df_lupa_pupa.groupby(['Executor','Type']).mean()
# Out:
#                Unnamed: 0      Salary
# Executor Type
# Loopa    A      46.000000   58.000000
#          B      24.000000  145.166667
#          C      31.666667  154.333333
#          D      31.857143  137.714286
#          E      23.500000  164.000000
#          F      20.000000  238.000000
# Pupa     A      16.000000  160.833333
#          B      41.000000   77.000000
#          C      23.000000   74.500000
#          D      14.000000  146.500000
#          E      19.800000  131.200000
#          F      25.750000  136.250000

# %%
concentrations = pd.read_csv('algae.csv')
concentrations.head(3)
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573

# %%
concentrations.groupby('genus').mean()
# Out:
# C:\Users\Александр\AppData\Local\Temp\ipykernel_10364\2737812142.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   concentrations.groupby('genus').mean()
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
concentrations.query("genus == 'Fucus'").alanin.describe().loc[['min', 'mean', 'max']]
# Out:
# min     0.346431
# mean    3.566411
# max     6.641303
# Name: alanin, dtype: float64

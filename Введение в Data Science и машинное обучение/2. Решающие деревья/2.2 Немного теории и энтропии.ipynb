# %%
import pandas as pd
from sklearn import tree
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
dogs_data = pd.read_csv('dogs.csv')

# %%
dogs_data = dogs_data.drop('Unnamed: 0', axis=1)

dogs_X = dogs_data.iloc[:, :3]
dogs_y = dogs_data.iloc[:, 3]

dogs_clf = tree.DecisionTreeClassifier(criterion='entropy', random_state=0)
dogs_clf.fit(dogs_X, dogs_y)

tree.plot_tree(dogs_clf, feature_names=dogs_X.columns)
# Out:
# [Text(0.5, 0.75, 'Гавкает <= 0.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.25, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.75, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]')]

# %%
dogs_data.head()
# Out:
#    Unnamed: 0  Шерстист  Гавкает  Лазает по деревьям      Вид
# 0           0         1        1                   0  собачка
# 1           1         1        1                   0  собачка
# 2           2         1        1                   0  собачка
# 3           3         1        1                   0  собачка
# 4           4         1        0                   1    котик

# %%
cats_data = pd.read_csv('cats.csv')

# %%
cats_data = cats_data.drop('Unnamed: 0', axis=1)

cats_X = cats_data.iloc[:, :3]
cats_y = cats_data.iloc[:, 3]

cats_clf = tree.DecisionTreeClassifier(criterion='entropy', random_state=0)
cats_clf.fit(cats_X, cats_y)

tree.plot_tree(cats_clf, feature_names=cats_X.columns)
# Out:
# [Text(0.5, 0.75, 'Лазает по деревьям <= 0.5\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.25, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.75, 0.25, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]')]

# %%
cats_data.head(10)
# Out:
#    Шерстист  Гавкает  Лазает по деревьям      Вид
# 0         1        1                   0  собачка
# 1         1        1                   0  собачка
# 2         1        1                   0  собачка
# 3         1        1                   0  собачка
# 4         1        0                   1    котик
# 5         1        0                   1    котик
# 6         1        0                   1    котик
# 7         1        0                   1    котик
# 8         1        1                   1    котик
# 9         0        0                   1    котик

# %%
E_sh_sob=(1/1)*math.log2((1/1)) - 0
E_sh_kot=-(4/9)*math.log2((4/9)) - (5/9)*math.log2((5/9))
E_gav_sob=0 - (5/5)*math.log2((5/5))
E_gav_kot=-(4/5)*math.log2((4/5)) - (1/5)*math.log2((1/5))
E_laz_sob=0 - (6/6)*math.log2((6/6))
E_laz_kot=-(4/4)*math.log2((4/4)) - 0
print(E_sh_sob, E_sh_kot, E_gav_sob, E_gav_kot, E_laz_sob, E_laz_kot)
# Out:
# 0.0 0.9910760598382222 0.0 0.7219280948873623 0.0 -0.0

# %%
E = -(4/10)*math.log2(4/10) - (6/10)*math.log2(6/10)

IG_sh = E - (1/10)*E_sh_sob - (9/10)*E_sh_kot
IG_gav = E - (5/10)*E_gav_sob - (5/10)*E_gav_kot
IG_laz = E - (6/10)*E_laz_sob - (6/10)*E_laz_kot
print(IG_sh, IG_gav, IG_laz)
# Out:
# 0.07898214060026854 0.6099865470109874 0.9709505944546686
